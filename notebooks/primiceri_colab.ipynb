# %% [markdown]
# # Primiceri (2005) TVP-SVAR Replication
#
# Use this notebook in Google Colab after the repository is pushed to GitHub. Replace `REPO_URL` with the final repository URL.

# %%
REPO_URL = "https://github.com/<your-user>/primiceri-2005-tvp-svar-replication.git"
REPO_DIR = "primiceri-2005-tvp-svar-replication"

import os
from pathlib import Path

if not Path(REPO_DIR).exists():
    # !git clone {REPO_URL}
# %cd {REPO_DIR}

# %%
# %pip install -q -r requirements.txt

# %% [markdown]
# A short run is useful for testing the notebook. Increase the iteration count for serious results.

# %%
# !python scripts/run_replication.py --iterations 800 --burn 300 --seed 123 --refresh-data

# %%
from IPython.display import Image, display
for fig in [
    "outputs/figures/01_fred_proxy_data.png",
    "outputs/figures/02_stochastic_volatilities.png",
    "outputs/figures/03_policy_shock_irfs.png",
]:
    display(Image(fig))
